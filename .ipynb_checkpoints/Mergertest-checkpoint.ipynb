# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
merger_file= "blackhole_mergers.hdf5"
merger_data=h5py.File(merger_file, 'r')
print(type(merger_data))
# Out:
# <class 'h5py._hl.files.File'>

# %%
test=7.0

# %%
print(type(test))
# Out:
# <class 'float'>

# %%
merger_data.keys()
# Out:
# <KeysViewHDF5 ['Header', 'details', 'id_in', 'id_out', 'mass_in', 'mass_out', 'snapshot', 'time', 'tree']>

# %%
merger_time=np.array(merger_data['time'])

# %%
print(merger_time)
# Out:
# [0.101528 0.115385 0.132302 ... 0.99889  0.999112 0.999704]

# %%
print(np.array(merger_time))
# Out:
# [0.101528 0.115385 0.132302 ... 0.99889  0.999112 0.999704]

# %%
x=[1,1,43,5,3,56]
y=[2,4,43,33,3,2]
plt.plot(y)

# %%
plt.plot(merger_time)
