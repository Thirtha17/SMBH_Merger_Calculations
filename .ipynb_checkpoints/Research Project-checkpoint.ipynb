# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import scipy
import astropy

# %%
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u
import astropy
from astropy.cosmology import z_at_value
cosmo = FlatLambdaCDM(H0=67.74, Om0=0.3089, Tcmb0=2.725)
#cosmo.luminosity_distance(z).value

# %%
x = []
y = []
for line in open('LISAstrain.txt', 'r'):
    lines = [i for i in line.split()]
    x.append(float(lines[0]))
    y.append(float(lines[1]))
M_1list=np.array([1e6,1e7,1e7])
M_2list=np.array([1e6,1e6,1e7])
for ......
    M1=
    M2=
    
M=M_1+M_2
M_o=1
z=1
miu=(M_1*M_2)**(3/5)/M**(1/5)
#G=scipy.constants.gravitational_constant
#c=scipy.constants.speed_of_light
d_l=cosmo.luminosity_distance(z).value
pi=scipy.constants.pi
f_c=3.9*(M/(10**4*M_o))**-1*(1+z)**-1
h_c=8/(10**(1/2))*(miu)**(5/3)/((d_l*3.086e22)*(pi*f_c)**(2/3)
#print(G)
#print(miu)
#print(c)
#print(d_l)
#print(pi)
#print(f_c)
#print(h_c)
plt.scatter(f_c,h_c,label='Test 1')



plt.xlabel('Frequency, f')
plt.ylabel('Strain, h')
#plt.yticks(y)
plt.plot(x, y, label='LISA sensitivity')
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper right')
plt.show()
# Out:
# 6.6743e-11
# [ 870550.56329612 2464458.23711789 8705505.63296123]
# 299792458.0
# 6791.768790110993
# 3.141592653589793
# [0.00975    0.00177273 0.000975  ]
# [2.02403285e-68 3.68005973e-68 2.02403285e-67]

# %%
t1=np.array([1e6,1e7])
t2=np.array([1e8,1e9])
print(t1*t2)

print([1e6,1e7])
print(np.array([1e6,1e7]))
# Out:
# [1.e+14 1.e+16]
# [1000000.0, 10000000.0]
# [ 1000000. 10000000.]

# %%
#z_at_value(cosmo.age, 10*u.Gyr)

# %%
cosmo.age(1.3)
# Out:
# <Quantity 4.81830272 Gyr>

# %%
M_1=10e6
M_2=10e6
M=M_1+M_2
M_o=1
z=1
miu=(M_1*M_2)**(3/5)/M**(1/5)
c=3.9*(M/(10**4*M_o))**-1*(1+z)**-1
h_c=8/(10**(1/2))*miu**(5/3)/((scipy.constants.speed_of_light)**4*cosmo.luminosity_distance(z).value)*(2*scipy.constants.pi*f_c)**(2/3)
